# %% [markdown]
# ## Drone simulator - Notebook

# %% [markdown]
# This simulator is a drone environment simulation, "inherited" from OpenAI PettingZoe - mpe environment. The "parasites" are represented as green circles and the drones are represented as red circles. It aims to create an interactive environment where drones and enemies can navigate, interact, and potentially engage in strategic behaviors.
#
# The drones and enemies can move in various directions within the environment, allowing for dynamic movement patterns and interactions.
# The drones have additional capabilities, such as the ability to change colors, reach higher ground,open a lamp,providing them with increased versatility and strategic options.
#
# In addition to the drones and enemies, the environment features shadow zones, which are areas where both drones and enemies can enter. These shadow zones introduce an additional element to the simulation and can potentially affect the behavior and interactions of the entities within them.
#
# Overall, the simulator aims to provide a realistic and immersive simulation of a drone-based scenario, allowing for the exploration and analysis of various drone and enemy interactions within the simulated environment.

# %%
from IPython.core.display import HTML
from IPython.display import display
gif_url = "gifs/example.gif"
html = HTML(f'<img src="{gif_url}" />')
display(html)
# Out:
# <img src="gifs/example.gif" />

# %% [markdown]
#  There are 2 ways to initialize the environment:
#
#  1. Empty Constructor (Parameters from Setting File)
#     * Initialize the environment using an empty constructor.
#     * Read parameters from the settings file with predefined values.
#     * Allows easy configuration without modifying the code directly.

# %%
from CustomAgents import *
from Auxiliry import *
env = simple_tag_v3.env()

# %% [markdown]
#  2. Parameter Constructor
#     * Initialize the environment by directly passing parameters to the constructor.
#     * Parameters include render mode, agent and adversary counts, obstacle count, maximum cycles,
#       observation and factor dictionaries, and possible agent colors.
#     * Provides flexibility and customization for specific requirements or dynamic conditions.

# %%
env = simple_tag_v3.env(
    render_mode='human',
    num_parasites=5,
    num_drones=5,
    num_obstacles=1,
    max_cycles=1000,
    num_of_possible_colors_for_agent=4,
    lamp_flag=True,
    height_flag=True,
    landmark_colide=False,
    no_dead_flag=True,
    max_hit_drone=1,
    max_hit_parasite=2,

)

# %% [markdown]
# 1. `render_mode` - Determines the rendering mode for the simulation ('human' for visual rendering, 'rgb_array' for non-visual processing).
#                    Default value is 'human'.
#
# 2. `num_parasites` - Number of parasites (green agents) in the simulation.
#                      Default value is 5.
#
# 3. `num_adversaries` - Number of drones (red agents) in the simulation.
#                      Default value is 5.
#
# 4. `num_obstacles` - Number of shadowed fields/obstacles in the environment.
#                      Default value is 2.
#
# 5. `max_cycles` - Maximum number of cycles for the simulation.
#                      Default value is 1000.
#
# 6. `num_of_possible_colors_for_agent` - Number of possible colors available for the Drones.
#                      Default value is 3.
#
# 7. `render_object_shrinking` - Allows rendering to shrink when agents are out of bounds.
#                      Default value is 'True'.
#
# 8. `lamp_flag` - Flag indicating whether the drone can light a lamp.
#                      Default value is 'True'.
#
# 9. `height_flag` - Flag indicating whether the drone can change its height.
#                      Default value is 'False'.
#
# 10. `landmark_colide` - Flag indicating whether agents collide with the landmark and can't enter it.
#                      Default value is 'False'.
#
# 11. `no_dead_flag` - Flag indicating if drones and parasites can get killed - Original scenario.
#                      Default value is 'True'.
#
# 12. `max_hit_parasite` - Number of hits the parasite can take before being destroyed.
#                      Default value is 1.
#
# 13. `max_hit_drone` - Number of hits the drone can take before being destroyed.
#                      Default value is 1.
#
# 14. `out_of_bounds_reward` - Flag indicating penelization of agents for going out of bounds (if an agent distances himself from the enviorment center, he will get negative reward).
#                  Default value is 'True'.
#
# 15. `obs_dict` - Observation radius dictionary. Allows the definition of different observation radii for different agents.
#                  Default values: For the first 10 entities, observation radius values are '10', and for the next 10 entities, the observation radius is 0.1.
#
# 16. `factor_dict` -  Dictionary used to set factors for manipulating the agents' observation radius.
#                     All factor values are '1' by default.
#
# 17. `reward_dict` - Dictionary that configures the agents' rewards.
#                     Default values: The intial reward is only for entities coliison - +10 for drones and -10 for parasites. All other rewards are set to zero.

# %% [markdown]
# # Default values:
#
# All the default values are configured within a Python file named 'settings.py,' which can be located at the following path: "DroneProject/pettingzoo/mpe/simple_tag." Please be aware that any modifications made to this file will permanently alter the default environment values.

# %% [markdown]
# ## ACTIONS

# %% [markdown]
# All entities in this simulator have the ability to move in four directions: up, down, left, and right. An entity can also remain static (by using action number zero). Drones possess additional actions that can be enabled or disabled using flags in the envelope settings.
#
# These actions include:
#
# Lamp activation/deactivation: Drones are equipped with lamps that enhance their visibility in shadowy areas and enable them to signal nearby drones. The degree to which the lamp improves a drone's observation can be adjusted using the 'obs_dict' parameter in the envelope settings.
#
# Height adjustment: Drones feature a binary height attribute that enhances their ability to detect other drones while limiting their vision of parasites. You can modify the extent to which this feature extends a drone's vision through the 'obs_dict' parameter in the envelope settings.
#
# Color change: Drones can change their color to communicate with nearby drones. This color change action operates cyclically, meaning that using it once will trigger a cyclical color shift. The number of colors available to the drones can be specified in the envelope settings, with a maximum limit of six colors.

# %% [markdown]
# Using the next function, we can print the world's action's indexes.

# %%
print_action_dict(env)
# Out:
# ('0', 'stay in place')
# ('1', 'move left')
# ('2', 'move right')
# ('3', 'move down')
# ('4', 'move up')
# (5, 'lamp action')
# (6, 'get height action')
# (7, 'change color action')

# %% [markdown]
# As you can see, the agent can move to any direction, also, the agent can preform the following actions: (if the corresponding flag is on)
# * activate/deactivate a lamp.
#  * get to higher grounds or get back to normal height.
#   * change its color(if it's a drone).

# %% [markdown]
# Up Down Right Left movments:

# %%
gif_url = "gifs/UDLR.gif"
html = HTML(f'<img src="{gif_url}" />')
display(html)
# Out:
# <img src="gifs/UDLR.gif" />

# %% [markdown]
# Activate/Deactivate Lamp action:

# %%
gif_url = "gifs/lamp.gif"
html = HTML(f'<img src="{gif_url}" />')
display(html)
# Out:
# <img src="gifs/lamp.gif" />

# %% [markdown]
# Ascend/Descend action(height):

# %%
gif_url = "gifs/height.gif"
html = HTML(f'<img src="{gif_url}" />')
display(html)
# Out:
# <img src="gifs/height.gif" />

# %% [markdown]
# Change color action:

# %%
gif_url = "gifs/color.gif"
html = HTML(f'<img src="{gif_url}" />')
display(html)
# Out:
# <img src="gifs/color.gif" />

# %% [markdown]
# ## OBSERVATIONS

# %% [markdown]
# In this scenario, multiple agents exist in a world, each with its observations. The observations include the lamp status, whether the agent is a drone (with a color index if applicable), and a list of data about visible agents: type of agent, relative distance, and color index (if they are drones). This data enables the agents to make informed decisions based on their environment and the attributes of other agents they can see (each agent has its on radius).
#
# The observation format:
# (is the agent a drone?,lamp status, if drone - what is its color index,is it destroyed)
# followed by a list of all visible agents,each entry looks like this:
# (is the agent a drone?, its relative_distance,its color index).
#
# example of an observation of a drone with lamp off and color index 2, still alive:
# [True, False, 2, True, (True, array([-0.81258817, -1.22620661]), 2), (True, array([ 0.63219806, -1.53451418]), 2), (True, array([-1.91364366, -0.67692917]), 3), (True, array([-0.64812583, -0.18377225])]
#
# after the agent takes a step in the environment, you can use env.last()[0] to get the observations of the agent.
#
# Each agent has an observation radius that is set using 2 objects in the environment:
# * obs_dict - sets the agents initial observation radius.
# * factor_dict - used to manipulate the agent's observation radius in specific situations.
#
# obs_dict: A dictionary of (key=radius, value=num_of_agents_with_radius).
# This dictionary helps set the observation radius for each agent.
#  For instance, in an enviorment with 12 agents, 4 drones and 8 parasites using this observation dictionary {3:2, 0.3:6, 1:4}:
# The first two agents(drones) have a radius of 3, the next six agents(2 drones,4 parasites) have a radius of 0.3, and the last four agents(parasites) have a radius of 1.
#  **NOTE: WHEN COUNTING THE AGENTS, DRONES COMES BEFORE PARASITES!**
#
# If the total number of agent in obs_dict is greater than the number of good agents -
# we ignore the last radiuses in the dict.
# If the total number of agent in obs_dict is smaller than the number of good agents -
#   we assume the remaining agents see in a default radius of 2.
#
#
# factor_dict: The default factor for each parameter is 1
#                           The factors are multiplied by the observation radius, so it's recommended to give values that are lower than 1 for interference factors,
#                           and values that are higher than 1 for improvement factors.
#
# The 'factor_dict' factors:
# * 'shadow_interference_factor' - Used when an agent is inside a landmark(shadow) and he's seeing another agent.
# * 'lamp_improvement_factor' - Used when an agent lamp is on and his not inside a shadow and his seeing another agent.
# * 'shadow_interference_factor' - Used when an agent sees a different agent in the shadow.
# * 'light_in_shadow_factor' - Used when an agent sees another agent in the shadow and the other agent has its lamp on.
# * 'height_adversary_factor' - Used when an agent is in high height, and he's seeing another drone.
# * 'height_non_adversary_factor' - Used when an agent is in high height, and he's seeing a parasite.
# * 'height_other_factor' - Used when an agent is in low height, and he's seeing another drone in high height.

# %% [markdown]
# High observation radius:

# %%
gif_url = "gifs/high_radius.gif"
html = HTML(f'<img src="{gif_url}" />')
display(html)
# Out:
# <img src="gifs/high_radius.gif" />

# %% [markdown]
# Low observation radius:

# %%
gif_url = "gifs/low_radius.gif"
html = HTML(f'<img src="{gif_url}" />')
display(html)
# Out:
# <img src="gifs/low_radius.gif" />

# %% [markdown]
# ## REWARDS

# %% [markdown]
# Each type of agent receives different rewards based on specific scenarios that can happen.
#  The rewards value for each scenario is stored in a dictionary where the scenario is the key, and the corresponding reward is the value. Let's break down the rewards for drones and parasites:
#
# **Drone Rewards:**
# - `drone_collision`: When a drone collides with a parasite. Default value is +10.
# - `drone_in_shadow_lamp_on`: If a drone is in the shadow and its lamp is on.
# - `drone_in_shadow_lamp_off`: If a drone is in the shadow and its lamp is off.
# - `drone_lamp_active`: When a drone's lamp is active.
# - `drone_lamp_off`: If a drone deactivates its lamp.
# - `drone_turn_lamp_on`: When a drone successfully turns its lamp on.
# - `drone_in_height`: If a drone is at a certain height.
# - `drone_height_change`: When a drone changes its height.
# - `drone_color_change`: If a drone changes its color.
#
# **Parasite Rewards:**
# - `parasite_collision`: When a parasite collides with a drone. Default value is -10.
#
# **General Rewards:**
#  * Agents are penalized for exiting the screen, so that they can be caught by the adversaries.
#
#
#
# **All the rewards for which we didn't specify a default value have a default value of zero.**
#
# You can modify the reward value for a specific scenario by first initializing a dictionary. Add a new entry for the scenarios whose rewards you want to change, and then pass this dictionary as a parameter during the environment creation.
#
# reward_dict={}
# reward_dict["drone_collision"] = 10
# env = simple_tag_v3.env(
#     ...
#     ...
#     reward_dict=reward_dict,
#     ...
#     )

# %% [markdown]
# ## Obstacles and Shadows

# %% [markdown]
# By utilizing the 'num_obstacles' parameter within the envelope settings, we have the ability to introduce obstacles or shadows into the environment.
#
# Obstacles are represented as impenetrable circles, serving as barriers within the environment.
#
# On the other hand, shadows are depicted as penetrable circles that can disrupt the vision of entities. The degree to which shadows affect entity vision can be adjusted using the 'obs_dict' parameter within the envelope settings.
#
# You can choose to include either obstacles or shadows by toggling the 'landmark_colide' parameter. Set it to 'True' to introduce obstacles, and 'False' to introduce shadows.

# %% [markdown]
# ## Running the enviorment

# %% [markdown]
# To run the environment, you first need to have a function policy for each type of agent, drone or parasite.
#
# A function policy has 3 parameters:
# (observation, env, agent)
# and it should return an action index.

# %% [markdown]
# The simulator can be run in two ways:
# 1. Uniform Policies: All drones have the same policy, and all parasites have the same policy.
#
# To run it, use the function:
# run_env(env, drone_policy=chaseParasiteAgent,parasite_policy=staticAgent):

# %% [markdown]
# 2. Single agent: All drones follow the same policy except one drone that has its own policy. All parasites have the same policy.
#
# To run it, use the function:
# run_env_single(env,single_agent_policy,drone_policy=chaseParasiteAgent,parasite_policy=staticAgent):

# %% [markdown]
# 3. Multiple policies -  You can assign individual policies to each agent in the environment using a dictionary; agents not specified in the dictionary will adopt a default policy.
#  Example:
# policy_dic={}
# policy_dic["adversary_0"]=staticAgent
# policy_dic["adversary_1"]=chaseParasiteAgent
# policy_dic["agent_1"]=escapeFromDronesAgent
#
# **NOTE: Drone's base name is adversary and parasites base name is agent!!**
#
# To run it, use the function:
# run_env_multi_policy(env, policy_dic, drone_policy = chaseParasiteAgent, parasite_policy = staticAgent):

# %% [markdown]
# # Single agent envelope

# %% [markdown]
# Another way to utilize the simulator is through the single-agent envelope. This envelope provides support for individual agents while imposing a fixed policy on all other entities. **The drone and parasite policies must be specified during the envelope's initialization.**
#
# The single-agent envelope encompasses all the features of the standard environment. The key distinctions in execution are as follows:
#
# * Step Function: In the standard environment, the step function advances a single entity. In the single-agent envelope, the step function executes the desired action on the individual agent and then carries out all the fixed policies on the other entities within the environment.
#
# * Observe Function: This function returns the observation for the single agent. In the standard environment, this function provides the observation for a specified agent.
# Note:Similarly, in the single-agent environment, there are analogous functions that yield results exclusively for the single agent, as opposed to a particular agent (e.g., action_space and observation_space functions).
#
# * In this environment, the single agent is depicted in shades of yellow, distinguishing it from the other drones, which retain their regular shades of red coloring.

# %% [markdown]
# In the following GIF we can see a single agent environment, with static drones and parasites and a single drone agent.

# %%
gif_url = "gifs/single_env.gif"
html = HTML(f'<img src="{gif_url}" />')
display(html)
# Out:
# <img src="gifs/single_env.gif" />

# %% [markdown]
# # Custom Agents - Simple given policies

# %% [markdown]
# The simulator features several basic policies for entity behavior:
#
# 'chaseParasiteAgent' - This agent actively pursues the nearest parasite in a greedy manner. If there are no parasites within the agent's observation radius, the agent will take random actions.
#
# 'escapeFromDronesAgent' - This agent attempts to move away from the nearest drone in a greedy manner. If no drones are present within the agent's observation radius, the agent will take random actions.
#
# 'escapeFromParasiteAgent' - This agent strives to distance itself from the closest parasite in a greedy fashion. If there are no parasites within the agent's observation radius, the agent will take random actions.
#
# 'randomAgent' - This agent selects a random action, including the static action, during each iteration.
#
# 'staticAgent' - This agent does not perform any actions.

# %% [markdown]
# ## Example

# %% [markdown]
# Let's create an environment with 5 drones and 3 parasites, and no obstacles.
# The drones will have a radius of 1, and parasite radius of 0.00001.
# with 2 times better vision if its lamp is on and the drone is inside a shadow zone.
# The agents cannot get to higher heights.
# The drone will get a reward=20 for colliding with a parasite.
# **We will turn the no dead flag on.**

# %%
my_obs_dict = {1: 5, 0.00001: 3}
factors={}
reward_dict={}
reward_dict["drone_collision"] = 20
factors["light_in_shadow_factor"] = 2.0


env = simple_tag_v3.env(
    render_mode='human',
    num_drones=5,
    num_parasites=3,
    num_obstacles=0,
    max_cycles=1000,

    num_of_possible_colors_for_agent=4,
    lamp_flag=True,
    height_flag=False,
    landmark_colide=False,
    no_dead_flag=True,
    factor_dict = factors,
    reward_dict = reward_dict,
    obs_dict=my_obs_dict,

)

# %% [markdown]
# Let's see our action index dictionary.

# %%
print_action_dict(env)
# Out:
# ('0', 'stay in place')
# ('1', 'move left')
# ('2', 'move right')
# ('3', 'move down')
# ('4', 'move up')
# (5, 'lamp action')
# (6, 'change color action')

# %% [markdown]
# Let's proceed to execute the environment. We will employ a policy that directs drones to pursue parasites, while the parasites will exhibit random behavior.

# %%
env.reset()
run_env(env,chaseParasiteAgent,randomAgent)
# Out:
# [True, False, 0, False, (True, array([-0.36029543,  0.44754192]), 0), (True, array([ 0.90206714, -0.17826195]), 0), (True, array([-0.33140865, -0.15792403]), 0)]
# [True, False, 0, False, (True, array([ 0.36029543, -0.44754192]), 0), (True, array([ 0.02888678, -0.60546595]), 0)]
# [True, False, 0, False, (True, array([-0.90206714,  0.17826195]), 0), (True, array([ 0.00689125, -0.69777093]), 0), (False, array([0.23840674, 0.61683299]), 0), (False, array([ 0.09684778, -0.15981556]), 0)]
# [True, False, 0, False, (True, array([-0.00689125,  0.69777093]), 0), (False, array([0.08995653, 0.53795537]), 0)]
# [True, False, 0, False, (True, array([0.33140865, 0.15792403]), 0), (True, array([-0.02888678,  0.60546595]), 0), (False, array([-0.18505137, -0.83538408]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 0, False, (True, array([-0.36029543,  0.44754192]), 1), (True, array([ 0.90206714, -0.17826195]), 0), (True, array([-0.33140865, -0.15792403]), 0)]
# [True, False, 1, False, (True, array([ 0.36029543, -0.44754192]), 0), (True, array([ 0.02888678, -0.60546595]), 0)]
# [True, False, 0, False, (True, array([-0.90206714,  0.17826195]), 0), (True, array([ 0.00689125, -0.69777093]), 0), (False, array([0.23840674, 0.61683299]), 0), (False, array([ 0.09684778, -0.15981556]), 0)]
# [True, False, 0, False, (True, array([-0.00689125,  0.69777093]), 0), (False, array([0.08995653, 0.53795537]), 0)]
# [True, False, 0, False, (True, array([0.33140865, 0.15792403]), 0), (True, array([-0.02888678,  0.60546595]), 1), (False, array([-0.18505137, -0.83538408]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, True, 0, False, (True, array([-0.36029543,  0.44754192]), 1), (True, array([ 0.90206714, -0.20826195]), 0), (True, array([-0.33140865, -0.18792403]), 0)]
# [True, False, 1, False, (True, array([ 0.36029543, -0.44754192]), 0), (True, array([ 0.02888678, -0.63546595]), 0)]
# [True, False, 0, False, (True, array([-0.90206714,  0.20826195]), 0), (True, array([ 0.00689125, -0.63777093]), 0), (False, array([0.23840674, 0.68683299]), 0), (False, array([ 0.09684778, -0.12981556]), 0)]
# [True, False, 0, False, (True, array([-0.00689125,  0.63777093]), 0), (False, array([0.08995653, 0.50795537]), 0)]
# [True, False, 0, False, (True, array([0.33140865, 0.18792403]), 0), (True, array([-0.02888678,  0.63546595]), 1), (False, array([-0.18505137, -0.84538408]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, True, 0, False, (True, array([-0.36029543,  0.44754192]), 1), (True, array([ 0.90206714, -0.26076195]), 0), (True, array([-0.33140865, -0.24042403]), 0)]
# [True, False, 1, False, (True, array([ 0.36029543, -0.44754192]), 0), (True, array([ 0.02888678, -0.68796595]), 0)]
# [True, False, 0, False, (True, array([-0.90206714,  0.26076195]), 0), (True, array([ 0.00689125, -0.53277093]), 0), (False, array([0.27840674, 0.76933299]), 0), (False, array([ 0.13684778, -0.07731556]), 0)]
# [True, False, 0, False, (True, array([-0.00689125,  0.53277093]), 0), (False, array([0.12995653, 0.45545537]), 0)]
# [True, False, 0, False, (True, array([0.33140865, 0.24042403]), 0), (True, array([-0.02888678,  0.68796595]), 1), (False, array([-0.18505137, -0.86288408]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, True, 1, False, (True, array([-0.36029543,  0.44754192]), 1), (True, array([ 0.87206714, -0.33013695]), 0), (True, array([-0.36140865, -0.30979903]), 0)]
# [True, True, 1, False, (True, array([ 0.36029543, -0.44754192]), 1), (True, array([-0.00111322, -0.75734095]), 0)]
# [True, False, 0, False, (True, array([-0.87206714,  0.33013695]), 1), (True, array([ 0.00689125, -0.39402093]), 0), (False, array([0.30840674, 0.90120799]), 0), (False, array([ 0.16684778, -0.00794056]), 0)]
# [True, False, 0, False, (True, array([-0.00689125,  0.39402093]), 0), (False, array([0.15995653, 0.38608037]), 0)]
# [True, False, 0, False, (True, array([0.36140865, 0.30979903]), 1), (True, array([0.00111322, 0.75734095]), 1), (False, array([-0.18505137, -0.84600908]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, True, 1, False, (True, array([-0.36029543,  0.44754192]), 1), (True, array([ 0.87956714, -0.3821682 ]), 0), (True, array([-0.38390865, -0.39183028]), 0)]
# [True, True, 1, False, (True, array([ 0.36029543, -0.44754192]), 1), (True, array([-0.02361322, -0.8393722 ]), 0)]
# [True, False, 0, False, (True, array([-0.87956714,  0.3821682 ]), 1), (True, array([-0.02310875, -0.25995843]), 0), (False, array([0.15934778, 0.08409069]), 0)]
# [True, False, 0, False, (True, array([0.02310875, 0.25995843]), 0), (False, array([0.18245653, 0.34404912]), 0)]
# [True, False, 0, False, (True, array([0.38390865, 0.39183028]), 1), (True, array([0.02361322, 0.8393722 ]), 1), (False, array([-0.18505137, -0.80335283]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, True, 2, False, (True, array([-0.42029543,  0.44754192]), 1), (True, array([ 0.88519214, -0.42119164]), 0), (True, array([ 0.80958339, -0.55060319]), 0), (True, array([-0.43078365, -0.48335371]), 0)]
# [True, True, 1, False, (True, array([ 0.42029543, -0.44754192]), 2), (True, array([-0.01048822, -0.93089563]), 0)]
# [True, False, 0, False, (True, array([-0.88519214,  0.42119164]), 2), (True, array([-0.07560875, -0.12941155]), 0), (False, array([0.16372278, 0.15311413]), 0)]
# [True, False, 0, False, (True, array([-0.80958339,  0.55060319]), 2), (True, array([0.07560875, 0.12941155]), 0), (False, array([0.23933153, 0.28252568]), 0)]
# [True, False, 0, False, (True, array([0.43078365, 0.48335371]), 2), (True, array([0.01048822, 0.93089563]), 1), (False, array([-0.18505137, -0.74136065]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, True, 2, False, (True, array([-0.46529543,  0.47754192]), 1), (True, array([ 0.77442714, -0.45196061]), 0), (True, array([-0.4659399 , -0.58199629]), 0)]
# [True, False, 1, False, (True, array([ 0.46529543, -0.47754192]), 2)]
# [True, False, 0, False, (True, array([-0.14498375, -0.0015014 ]), 0), (False, array([0.13700403, 0.16488171]), 0)]
# [True, False, 0, False, (True, array([-0.77442714,  0.45196061]), 2), (True, array([0.14498375, 0.0015014 ]), 0), (False, array([0.28198778, 0.1663831 ]), 0)]
# [True, False, 0, False, (True, array([0.4659399 , 0.58199629]), 2), (False, array([-0.14505137, -0.66486651]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, True, 2, False, (True, array([-0.52904543,  0.50004192]), 1), (True, array([ 0.7176914 , -0.35196129]), 0), (True, array([-0.52230708, -0.68199629]), 0)]
# [True, False, 1, False, (True, array([ 0.52904543, -0.50004192]), 2)]
# [True, False, 0, False, (True, array([-0.22776437,  0.11979679]), 0), (False, array([0.08658414, 0.21305557]), 0)]
# [True, False, 0, False, (True, array([-0.7176914 ,  0.35196129]), 2), (True, array([ 0.22776437, -0.11979679]), 0), (False, array([0.31434852, 0.09325878]), 0)]
# [True, False, 0, False, (True, array([0.52230708, 0.68199629]), 2), (False, array([-0.11505137, -0.58147783]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, True, 2, False, (True, array([-0.57685793,  0.48691692]), 1), (True, array([ 0.70012473, -0.30701374]), 0), (True, array([-0.56458247, -0.81199629]), 0)]
# [True, False, 1, False, (True, array([ 0.57685793, -0.48691692]), 2)]
# [True, False, 0, False, (True, array([-0.26987957,  0.18066657]), 0), (False, array([0.08375436, 0.21913404]), 0)]
# [True, False, 0, False, (True, array([-0.70012473,  0.30701374]), 2), (True, array([ 0.26987957, -0.18066657]), 0), (False, array([0.35363394, 0.03846747]), 0)]
# [True, False, 0, False, (True, array([0.56458247, 0.81199629]), 2), (False, array([-0.09255137, -0.49393633]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, True, 2, False, (True, array([-0.6427173 ,  0.47707317]), 1), (True, array([ 0.68694973, -0.27330307]), 0)]
# [True, False, 1, False, (True, array([ 0.6427173 , -0.47707317]), 2)]
# [True, False, 0, False, (True, array([-0.27146597,  0.1963189 ]), 0), (False, array([0.04163203, 0.19369289]), 0)]
# [True, False, 0, False, (True, array([-0.68694973,  0.27330307]), 2), (True, array([ 0.27146597, -0.1963189 ]), 0), (False, array([0.36414915, 0.87647188]), 0), (False, array([ 0.313098  , -0.00262601]), 0)]
# [True, False, 0, False, (False, array([-0.07567637, -0.4032802 ]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, True, 2, False, (True, array([-0.66211183,  0.43969036]), 1), (True, array([ 0.70706848, -0.27802006]), 0)]
# [True, True, 1, False, (True, array([ 0.66211183, -0.43969036]), 2)]
# [True, False, 0, False, (True, array([-0.24265578,  0.17805815]), 0), (False, array([0.04371837, 0.99809759]), 0), (False, array([0.05004027, 0.14461203]), 0)]
# [True, False, 0, False, (True, array([-0.70706848,  0.27802006]), 2), (True, array([ 0.24265578, -0.17805815]), 0), (False, array([0.28637415, 0.82003944]), 0), (False, array([ 0.29269605, -0.03344612]), 0)]
# [True, False, 0, False, (False, array([-0.06302012, -0.27028811]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, True, 2, False, (True, array([-0.67665773,  0.41165325]), 1), (True, array([ 0.75215754, -0.28155781]), 0)]
# [True, True, 1, False, (True, array([ 0.67665773, -0.41165325]), 2)]
# [True, False, 0, False, (True, array([-0.19104813,  0.13436258]), 0), (False, array([-0.03300523,  0.91207769]), 0), (False, array([0.05634646, 0.07780138]), 0)]
# [True, False, 0, False, (True, array([-0.75215754,  0.28155781]), 2), (True, array([ 0.19104813, -0.13436258]), 0), (False, array([0.1580429, 0.7777151]), 0), (False, array([ 0.24739458, -0.0565612 ]), 0)]
# [True, False, 0, False, (False, array([-0.05352793, -0.14554403]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 2, False, (True, array([-0.65756715,  0.42062542]), 1), (True, array([ 0.93831673, -0.32580204]), 0), (True, array([ 0.81597434, -0.25421112]), 0)]
# [True, False, 1, False, (True, array([ 0.65756715, -0.42062542]), 2)]
# [True, False, 0, False, (True, array([-0.93831673,  0.32580204]), 2), (True, array([-0.12234239,  0.07159091]), 0), (False, array([-0.05054793,  0.81756276]), 0), (False, array([ 0.0610761, -0.0023066]), 0)]
# [True, False, 0, False, (True, array([-0.81597434,  0.25421112]), 2), (True, array([ 0.12234239, -0.07159091]), 0), (False, array([0.07179446, 0.74597185]), 0), (False, array([ 0.18341849, -0.07389752]), 0)]
# [True, False, 0, False, (False, array([-0.04640879, -0.06698598]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([-0.64324922,  0.42735454]), 1), (True, array([ 0.91767633, -0.25165   ]), 0), (True, array([ 0.89383694, -0.23370111]), 0), (False, array([0.87094507, 0.48846331]), 0)]
# [True, True, 1, False, (True, array([ 0.64324922, -0.42735454]), 3)]
# [True, False, 0, False, (True, array([-0.91767633,  0.25165   ]), 3), (True, array([-0.02383939,  0.01794889]), 0), (False, array([-0.04673126,  0.7401133 ]), 0), (False, array([ 0.09857071, -0.04551413]), 0)]
# [True, False, 0, False, (True, array([-0.89383694,  0.23370111]), 3), (True, array([ 0.02383939, -0.01794889]), 0), (False, array([-0.02289187,  0.72216441]), 0), (False, array([ 0.12241011, -0.06346302]), 0)]
# [True, False, 0, False, (False, array([-0.08106943,  0.01693256]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([-0.63251077,  0.43240139]), 1), (True, array([ 0.87548232, -0.19779225]), 0), (True, array([ 0.97511274, -0.21415153]), 0), (False, array([0.85832727, 0.44599024]), 0)]
# [True, True, 1, False, (True, array([ 0.63251077, -0.43240139]), 3)]
# [True, False, 0, False, (True, array([-0.87548232,  0.19779225]), 3), (True, array([ 0.09963042, -0.01635928]), 0), (False, array([-0.01715505,  0.64378248]), 0), (False, array([ 0.21724024, -0.07857429]), 0)]
# [True, False, 0, False, (True, array([-0.97511274,  0.21415153]), 3), (True, array([-0.09963042,  0.01635928]), 0), (False, array([-0.11678547,  0.66014177]), 0), (False, array([ 0.11760982, -0.06221501]), 0)]
# [True, False, 0, False, (False, array([-0.15662008, -0.00165597]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([-0.65445694,  0.46618652]), 1), (True, array([ 0.92491443, -0.22278589]), 0), (True, array([ 0.9400765, -0.1272153]), 0), (False, array([0.81886392, 0.41413544]), 0)]
# [True, True, 1, False, (True, array([ 0.65445694, -0.46618652]), 3)]
# [True, False, 0, False, (True, array([-0.92491443,  0.22278589]), 3), (True, array([0.01516207, 0.0955706 ]), 0), (False, array([-0.10605051,  0.63692133]), 0), (False, array([ 0.21008023, -0.04486953]), 0)]
# [True, False, 0, False, (True, array([-0.9400765,  0.1272153]), 3), (True, array([-0.01516207, -0.0955706 ]), 0), (False, array([-0.12121258,  0.54135074]), 0), (False, array([ 0.19491816, -0.14044013]), 0)]
# [True, False, 0, False, (False, array([-0.26586331, -0.03834925]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([-0.67091656,  0.49152537]), 1), (True, array([ 0.91360106, -0.23358593]), 0), (True, array([ 0.96213821, -0.06999088]), 0), (False, array([0.75926641, 0.39024434]), 0)]
# [True, True, 1, False, (True, array([ 0.67091656, -0.49152537]), 3)]
# [True, False, 0, False, (True, array([-0.91360106,  0.23358593]), 3), (True, array([0.04853714, 0.16359504]), 0), (False, array([-0.15433465,  0.62383026]), 0), (False, array([ 0.22309796, -0.02753631]), 0)]
# [True, False, 0, False, (True, array([-0.96213821,  0.06999088]), 3), (True, array([-0.04853714, -0.16359504]), 0), (False, array([-0.2028718 ,  0.46023522]), 0), (False, array([ 0.17456082, -0.19113135]), 0)]
# [True, False, 0, False, (False, array([-0.27779572, -0.06586922]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([-0.71326128,  0.51052951]), 1), (True, array([ 0.89677487, -0.29426257]), 0), (True, array([ 9.59369041e-01, -5.53521637e-04]), 0), (False, array([0.68456828, 0.41232601]), 0)]
# [True, True, 1, False, (True, array([ 0.71326128, -0.51052951]), 3)]
# [True, False, 0, False, (True, array([-0.89677487,  0.29426257]), 3), (True, array([0.06259417, 0.29370905]), 0), (False, array([-0.21220659,  0.70658858]), 0), (False, array([0.21120243, 0.03804022]), 0)]
# [True, False, 0, False, (True, array([-9.59369041e-01,  5.53521637e-04]), 3), (True, array([-0.06259417, -0.29370905]), 0), (False, array([-0.27480076,  0.41287954]), 0), (False, array([ 0.14860825, -0.25566882]), 0)]
# [True, False, 0, False, (False, array([-0.25674504, -0.04650919]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([-0.77501981,  0.49478261]), 1), (True, array([ 0.88415522, -0.33977005]), 0), (True, array([0.92729217, 0.0215245 ]), 0), (False, array([0.59854468, 0.42888727]), 0)]
# [True, True, 1, False, (True, array([ 0.77501981, -0.49478261]), 3)]
# [True, False, 0, False, (True, array([-0.88415522,  0.33977005]), 3), (True, array([0.04313694, 0.36129455]), 0), (False, array([-0.28561055,  0.76865732]), 0), (False, array([0.17228077, 0.08722262]), 0)]
# [True, False, 0, False, (True, array([-0.92729217, -0.0215245 ]), 3), (True, array([-0.04313694, -0.36129455]), 0), (False, array([-0.32874749,  0.40736277]), 0), (False, array([ 0.12914383, -0.27407193]), 0)]
# [True, False, 0, False, (False, array([-0.21095702, -0.07198917]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([ 0.87469049, -0.37390067]), 0), (True, array([0.87323451, 0.00808301]), 0), (False, array([0.46402698, 0.44130821]), 0)]
# [True, False, 1, False]
# [True, False, 0, False, (True, array([-0.87469049,  0.37390067]), 3), (True, array([-0.00145598,  0.38198368]), 0), (False, array([-0.41066351,  0.81520888]), 0), (False, array([0.11308953, 0.12410942]), 0)]
# [True, False, 0, False, (True, array([-0.87323451, -0.00808301]), 3), (True, array([ 0.00145598, -0.38198368]), 0), (False, array([-0.40920753,  0.4332252 ]), 0), (False, array([ 0.11454552, -0.25787426]), 0)]
# [True, False, 0, False, (False, array([-0.10661601, -0.09109915]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([ 0.86884135, -0.39950311]), 0), (True, array([ 0.80394067, -0.03200259]), 0), (False, array([0.29438811, 0.45061943]), 0), (False, array([ 0.90753745, -0.28772859]), 0)]
# [True, False, 1, False]
# [True, False, 0, False, (True, array([-0.86884135,  0.39950311]), 3), (True, array([-0.06490067,  0.36750053]), 0), (False, array([0.03869611, 0.11177452]), 0)]
# [True, False, 0, False, (True, array([-0.80394067,  0.03200259]), 3), (True, array([ 0.06490067, -0.36750053]), 0), (False, array([-0.50955256,  0.48262202]), 0), (False, array([ 0.10359678, -0.255726  ]), 0)]
# [True, False, 0, False, (False, array([ 0.04163975, -0.10543164]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([ 0.83945434, -0.38871778]), 0), (True, array([ 0.72697014, -0.09207962]), 0), (False, array([0.1421588 , 0.45759002]), 0), (False, array([ 0.82235537, -0.35619443]), 0)]
# [True, False, 1, False]
# [True, False, 0, False, (True, array([-0.83945434,  0.38871778]), 3), (True, array([-0.11248419,  0.29663816]), 0), (False, array([-0.01709897,  0.03252335]), 0)]
# [True, False, 0, False, (True, array([-0.72697014,  0.09207962]), 3), (True, array([ 0.11248419, -0.29663816]), 0), (False, array([-0.58481134,  0.54966963]), 0), (False, array([ 0.09538523, -0.26411481]), 0)]
# [True, False, 0, False, (False, array([ 0.14283157, -0.11618101]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([ 0.81521632, -0.38697704]), 0), (True, array([ 0.66924225, -0.19713739]), 0), (False, array([-0.01201317,  0.43281796]), 0), (False, array([ 0.72066656, -0.43119554]), 0)]
# [True, False, 1, False]
# [True, False, 0, False, (True, array([-0.81521632,  0.38697704]), 3), (True, array([-0.14597407,  0.18983966]), 0), (False, array([-0.09454976, -0.04421849]), 0)]
# [True, False, 0, False, (True, array([-0.66924225,  0.19713739]), 3), (True, array([ 0.14597407, -0.18983966]), 0), (False, array([-0.68125542,  0.62995534]), 0), (False, array([ 0.05142432, -0.23405815]), 0)]
# [True, False, 0, False, (False, array([ 0.18727954, -0.115902  ]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([ 0.83810763, -0.46378897]), 0), (True, array([ 0.62594632, -0.33593072]), 0), (False, array([-0.12764216,  0.34423891]), 0), (False, array([ 0.64333014, -0.43932889]), 0)]
# [True, False, 1, False]
# [True, False, 0, False, (True, array([-0.83810763,  0.46378897]), 3), (True, array([-0.2121613 ,  0.12785825]), 0), (False, array([-0.19477748,  0.02446008]), 0)]
# [True, False, 0, False, (True, array([-0.62594632,  0.33593072]), 3), (True, array([ 0.2121613 , -0.12785825]), 0), (False, array([ 0.01738382, -0.10339818]), 0)]
# [True, False, 0, False, (False, array([ 0.15061552, -0.11569275]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([ 0.59347438, -0.50002571]), 0), (False, array([-0.2143639 ,  0.24780463]), 0), (False, array([ 0.60664845, -0.48416477]), 0)]
# [True, False, 2, False]
# [True, False, 0, False, (True, array([-0.2504811 ,  0.04263634]), 0), (False, array([-0.23730703,  0.05849728]), 0)]
# [True, False, 0, False, (True, array([-0.59347438,  0.50002571]), 3), (True, array([ 0.2504811 , -0.04263634]), 0), (False, array([0.01317407, 0.01586094]), 0)]
# [True, False, 0, False, (False, array([ 0.13311751, -0.11553581]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([ 0.56577948, -0.66322517]), 0), (False, array([-0.2394052 ,  0.14547891]), 0), (False, array([ 0.58247812, -0.52766347]), 0)]
# [True, False, 2, False]
# [True, False, 0, False, (True, array([-0.25256189, -0.03140831]), 0), (False, array([-0.23586325,  0.10415339]), 0)]
# [True, False, 0, False, (True, array([-0.56577948,  0.66322517]), 3), (True, array([0.25256189, 0.03140831]), 0), (False, array([0.01669865, 0.1355617 ]), 0)]
# [True, False, 0, False, (False, array([ 0.129994 , -0.1154181]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([ 0.49233365, -0.84145393]), 0), (False, array([-0.25818618,  0.03873463]), 0), (False, array([ 0.61545611, -0.50214671]), 0)]
# [True, False, 2, False]
# [True, False, 0, False, (True, array([-0.27679714, -0.11277096]), 0), (False, array([-0.15367468,  0.22653626]), 0)]
# [True, False, 0, False, (True, array([-0.49233365,  0.84145393]), 3), (True, array([0.27679714, 0.11277096]), 0), (False, array([0.12312246, 0.33930722]), 0)]
# [True, False, 0, False, (False, array([ 0.13765137, -0.11532982]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (False, array([-0.24227191, -0.08132358]), 0), (False, array([ 0.6701896 , -0.48300913]), 0)]
# [True, True, 2, False]
# [True, False, 0, False, (True, array([-0.26497358, -0.14379296]), 0), (False, array([-0.06203325,  0.31832342]), 0)]
# [True, False, 0, False, (True, array([0.26497358, 0.14379296]), 0), (False, array([0.20294033, 0.46211638]), 0)]
# [True, False, 0, False, (False, array([ 0.11339439, -0.07526361]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (False, array([-0.16033621, -0.17136724]), 0), (False, array([ 0.70123972, -0.46865594]), 0)]
# [True, False, 2, False]
# [True, False, 0, False, (True, array([-0.25610591, -0.16705946]), 0), (False, array([-0.03330219,  0.35716379]), 0)]
# [True, False, 0, False, (True, array([0.25610591, 0.16705946]), 0), (False, array([0.22280373, 0.52422325]), 0)]
# [True, False, 0, False, (False, array([ 0.06520166, -0.04521396]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (False, array([-0.06888444, -0.23889999]), 0), (False, array([ 0.75452731, -0.45789105]), 0)]
# [True, False, 2, False]
# [True, False, 0, False, (True, array([-0.24945516, -0.18450933]), 0), (False, array([-0.01175388,  0.35629407]), 0)]
# [True, False, 0, False, (True, array([0.24945516, 0.18450933]), 0), (False, array([-0.58571046,  0.75979447]), 0), (False, array([0.23770128, 0.5408034 ]), 0)]
# [True, False, 0, False, (False, array([-0.00094286, -0.02267673]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (False, array([-0.00029561, -0.25954955]), 0), (False, array([ 0.794493  , -0.37981739]), 0)]
# [True, False, 2, False]
# [True, False, 0, False, (True, array([-0.2444671 , -0.19759674]), 0), (False, array([-0.79038126,  0.48590962]), 0), (False, array([0.00440734, 0.36564178]), 0)]
# [True, False, 0, False, (True, array([0.2444671 , 0.19759674]), 0), (False, array([-0.54591416,  0.68350636]), 0), (False, array([0.24887444, 0.56323852]), 0)]
# [True, False, 0, False, (False, array([-0.00551622, -0.0578067 ]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (False, array([ 0.05114602, -0.24503672]), 0), (False, array([ 0.82446726, -0.33126213]), 0)]
# [True, False, 2, False]
# [True, False, 0, False, (True, array([-0.24072605, -0.20741229]), 0), (False, array([-0.75679298,  0.38887798]), 0), (False, array([0.01652826, 0.30265256]), 0)]
# [True, False, 0, False, (True, array([0.24072605, 0.20741229]), 0), (False, array([-0.51606694,  0.59629027]), 0), (False, array([0.25725431, 0.51006486]), 0)]
# [True, False, 0, False, (False, array([-0.01573787, -0.25561159]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([ 0.82132901, -0.49025635]), 0), (True, array([ 0.58340875, -0.7050303 ]), 0), (False, array([ 0.08972724, -0.20415209]), 0), (False, array([ 0.84694797, -0.2648457 ]), 0)]
# [True, False, 2, False]
# [True, False, 0, False, (True, array([-0.82132901,  0.49025635]), 3), (True, array([-0.23792026, -0.21477396]), 0), (False, array([-0.73160178,  0.28610425]), 0), (False, array([0.02561895, 0.22541065]), 0)]
# [True, False, 0, False, (True, array([-0.58340875,  0.7050303 ]), 3), (True, array([0.23792026, 0.21477396]), 0), (False, array([-0.49368152,  0.50087821]), 0), (False, array([0.26353921, 0.44018461]), 0)]
# [True, False, 0, False, (False, array([-0.03525358, -0.47592966]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([ 0.83137152, -0.32251258]), 0), (True, array([ 0.5955556 , -0.54280779]), 0), (False, array([ 0.15866315, -0.14348863]), 0), (False, array([ 0.90380849, -0.18503337]), 0)]
# [True, True, 2, False]
# [True, False, 0, False, (True, array([-0.83137152,  0.32251258]), 3), (True, array([-0.23581592, -0.22029521]), 0), (False, array([-0.67270837,  0.17902396]), 0), (False, array([0.07243697, 0.13747921]), 0)]
# [True, False, 0, False, (True, array([-0.5955556 ,  0.54280779]), 3), (True, array([0.23581592, 0.22029521]), 0), (False, array([-0.43689245,  0.39931916]), 0), (False, array([0.30825289, 0.35777442]), 0)]
# [True, False, 0, False, (False, array([-0.08989037, -0.61116822]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([ 0.83913416, -0.14034593]), 0), (True, array([ 0.60466574, -0.3611409 ]), 0), (False, array([ 0.17036508, -0.06799103]), 0), (False, array([ 0.94645389, -0.05517412]), 0)]
# [True, True, 2, False]
# [True, False, 0, False, (True, array([-0.83913416,  0.14034593]), 3), (True, array([-0.23446842, -0.22079497]), 0), (False, array([-0.66876907,  0.07235491]), 0), (False, array([0.10731973, 0.08517181]), 0)]
# [True, False, 0, False, (True, array([-0.60466574,  0.3611409 ]), 3), (True, array([0.23446842, 0.22079497]), 0), (False, array([-0.43430065,  0.29314988]), 0), (False, array([0.34178815, 0.30596678]), 0)]
# [True, False, 0, False, (False, array([-0.13086796, -0.68259713]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([0.81518017, 0.02132703]), 0), (True, array([ 0.58166051, -0.19942953]), 0), (False, array([0.14914153, 0.02863217]), 0), (False, array([0.94843793, 0.04222031]), 0)]
# [True, True, 3, False]
# [True, False, 0, False, (True, array([-0.81518017, -0.02132703]), 3), (True, array([-0.23351966, -0.22075656]), 0), (False, array([-0.66603863,  0.00730515]), 0), (False, array([0.13325777, 0.02089329]), 0)]
# [True, False, 0, False, (True, array([-0.58166051,  0.19942953]), 3), (True, array([0.23351966, 0.22075656]), 0), (False, array([-0.43251897,  0.22806171]), 0), (False, array([0.36677742, 0.24164985]), 0)]
# [True, False, 0, False, (False, array([-0.16160115, -0.66616882]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([0.79721467, 0.14258174]), 0), (True, array([ 0.56440659, -0.078146  ]), 0), (False, array([0.10322387, 0.10109957]), 0), (False, array([0.87992597, 0.11526614]), 0)]
# [True, True, 0, False]
# [True, False, 0, False, (True, array([-0.79721467, -0.14258174]), 3), (True, array([-0.23280808, -0.22072775]), 0), (False, array([-0.6939908 , -0.04148217]), 0), (False, array([ 0.0827113, -0.0273156]), 0)]
# [True, False, 0, False, (True, array([-0.56440659,  0.078146  ]), 3), (True, array([0.23280808, 0.22072775]), 0), (False, array([-0.46118271,  0.17924558]), 0), (False, array([0.31551938, 0.19341215]), 0)]
# [True, False, 0, False, (False, array([-0.18465104, -0.62384759]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([0.7837405 , 0.23352277]), 0), (True, array([0.55146615, 0.01281664]), 0), (False, array([0.03878563, 0.15545012]), 0), (False, array([0.79854205, 0.21005052]), 0)]
# [True, True, 1, False]
# [True, False, 0, False, (True, array([-0.7837405 , -0.23352277]), 3), (True, array([-0.23227435, -0.22070613]), 0), (False, array([-0.74495487, -0.07807265]), 0), (False, array([ 0.01480156, -0.02347225]), 0)]
# [True, False, 0, False, (True, array([-0.55146615, -0.01281664]), 3), (True, array([0.23227435, 0.22070613]), 0), (False, array([-0.51268052,  0.14263348]), 0), (False, array([0.2470759 , 0.19723388]), 0)]
# [True, False, 0, False, (False, array([-0.20193846, -0.60210666]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([0.7376515 , 0.31361214]), 0), (True, array([0.54176082, 0.08103863]), 0), (False, array([-0.03954306,  0.15621304]), 0), (False, array([0.70348747, 0.26925522]), 0)]
# [True, True, 2, False]
# [True, False, 0, False, (True, array([-0.7376515 , -0.31361214]), 3), (True, array([-0.19589069, -0.23257351]), 0), (False, array([-0.77719456, -0.1573991 ]), 0), (False, array([-0.03416403, -0.04435692]), 0)]
# [True, False, 0, False, (True, array([-0.54176082, -0.08103863]), 3), (True, array([0.19589069, 0.23257351]), 0), (False, array([-0.58130387,  0.07517441]), 0), (False, array([0.16172666, 0.18821659]), 0)]
# [True, False, 0, False, (False, array([-0.21490403, -0.55580097]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([0.65121135, 0.39593982]), 0), (True, array([0.56448182, 0.10220512]), 0), (False, array([-0.09828957,  0.12678522]), 0), (False, array([0.68406995, 0.20139808]), 0)]
# [True, True, 2, False]
# [True, False, 0, False, (True, array([-0.65121135, -0.39593982]), 3), (True, array([-0.08672953, -0.2937347 ]), 0), (False, array([-0.74950092, -0.2691546 ]), 0), (False, array([ 0.0328586 , -0.19454174]), 0)]
# [True, False, 0, False, (True, array([-0.56448182, -0.10220512]), 3), (True, array([0.08672953, 0.2937347 ]), 0), (False, array([-0.66277139,  0.02458011]), 0), (False, array([0.11958813, 0.09919296]), 0)]
# [True, False, 0, False, (False, array([-0.1846282, -0.4910717]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([0.6284918, 0.4523599]), 0), (True, array([0.58152257, 0.11807998]), 0), (False, array([-0.14234946,  0.07471436]), 0), (False, array([0.62739624, 0.06583091]), 0)]
# [True, True, 3, False]
# [True, False, 0, False, (True, array([-0.6284918, -0.4523599]), 3), (True, array([-0.04696923, -0.33427991]), 0), (False, array([-0.77084126, -0.37764554]), 0), (False, array([-0.00109556, -0.38652899]), 0)]
# [True, False, 0, False, (True, array([-0.58152257, -0.11807998]), 3), (True, array([0.04696923, 0.33427991]), 0), (False, array([-0.72387203, -0.04336562]), 0), (False, array([ 0.04587367, -0.05224907]), 0)]
# [True, False, 0, False, (False, array([-0.16192133, -0.45252474]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([0.61145214, 0.43467496]), 0), (True, array([0.62430313, 0.09998613]), 0), (False, array([-0.13539437,  0.00566121]), 0), (False, array([ 0.54489096, -0.06584447]), 0)]
# [True, True, 3, False]
# [True, False, 0, False, (True, array([-0.61145214, -0.43467496]), 3), (True, array([ 0.01285099, -0.33468882]), 0), (False, array([-0.74684651, -0.42901374]), 0), (False, array([-0.06656118, -0.50051942]), 0)]
# [True, False, 0, False, (True, array([-0.62430313, -0.09998613]), 3), (True, array([-0.01285099,  0.33468882]), 0), (False, array([-0.7596975 , -0.09432492]), 0), (False, array([-0.07941218, -0.1658306 ]), 0)]
# [True, False, 0, False, (False, array([-0.1447734 , -0.39774733]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([0.62867239, 0.39141125]), 0), (True, array([0.6497907 , 0.09809988]), 0), (False, array([-0.10017806, -0.00612865]), 0), (False, array([ 0.50960985, -0.20628514]), 0)]
# [True, False, 3, False]
# [True, False, 0, False, (True, array([-0.62867239, -0.39141125]), 3), (True, array([ 0.0211183 , -0.29331137]), 0), (False, array([-0.72885045, -0.3975399 ]), 0), (False, array([-0.11906254, -0.59769638]), 0)]
# [True, False, 0, False, (True, array([-0.6497907 , -0.09809988]), 3), (True, array([-0.0211183 ,  0.29331137]), 0), (False, array([-0.74996875, -0.10422852]), 0), (False, array([-0.14018085, -0.30438501]), 0)]
# [True, False, 0, False, (False, array([-0.13181088, -0.33165453]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([0.67158756, 0.32896347]), 0), (True, array([0.69890635, 0.06668519]), 0), (False, array([-0.08376587, -0.01497104]), 0), (False, array([ 0.513149  , -0.31161563]), 0)]
# [True, False, 3, False]
# [True, False, 0, False, (True, array([-0.67158756, -0.32896347]), 3), (True, array([ 0.02731879, -0.26227828]), 0), (False, array([-0.75535343, -0.34393451]), 0), (False, array([-0.15843856, -0.64057911]), 0)]
# [True, False, 0, False, (True, array([-0.69890635, -0.06668519]), 3), (True, array([-0.02731879,  0.26227828]), 0), (False, array([-0.78267222, -0.08165623]), 0), (False, array([-0.18575735, -0.37830082]), 0)]
# [True, False, 0, False, (False, array([-0.12201638, -0.25707997]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([0.70918525, 0.25062336]), 0), (True, array([0.7411544 , 0.01161989]), 0), (False, array([-0.0506341 , -0.02461138]), 0), (False, array([ 0.52121467, -0.35211778]), 0)]
# [True, False, 3, False]
# [True, False, 0, False, (True, array([-0.70918525, -0.25062336]), 3), (True, array([ 0.03196915, -0.23900347]), 0), (False, array([-0.75981935, -0.27523475]), 0), (False, array([-0.18797058, -0.60274115]), 0)]
# [True, False, 0, False, (True, array([-0.7411544 , -0.01161989]), 3), (True, array([-0.03196915,  0.23900347]), 0), (False, array([-0.7917885 , -0.03623128]), 0), (False, array([-0.21993973, -0.36373768]), 0)]
# [True, False, 0, False, (False, array([-0.11461861, -0.17614652]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([0.72809921, 0.1548472 ]), 0), (True, array([ 0.76355613, -0.06670016]), 0), (False, array([-0.07435388, -0.0858838 ]), 0), (False, array([ 0.51797962, -0.38951547]), 0)]
# [True, True, 3, False]
# [True, False, 0, False, (True, array([-0.72809921, -0.1548472 ]), 3), (True, array([ 0.03545692, -0.22154736]), 0), (False, array([-0.80245309, -0.240731  ]), 0), (False, array([-0.21011959, -0.54436268]), 0)]
# [True, False, 0, False, (True, array([-0.76355613,  0.06670016]), 3), (True, array([-0.03545692,  0.22154736]), 0), (False, array([-0.83791002, -0.01918365]), 0), (False, array([-0.24557651, -0.32281532]), 0)]
# [True, False, 0, False, (False, array([-0.10903321, -0.09044514]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([0.71049569, 0.02298171]), 0), (True, array([ 0.74856845, -0.18547356]), 0), (False, array([-0.1857217 , -0.19190485]), 0), (False, array([ 0.48376435, -0.40759711]), 0)]
# [True, True, 3, False]
# [True, False, 0, False, (True, array([-0.71049569, -0.02298171]), 3), (True, array([ 0.03807275, -0.20845527]), 0), (False, array([-0.89621739, -0.21488656]), 0), (False, array([-0.22673135, -0.43057882]), 0)]
# [True, False, 0, False, (True, array([-0.74856845,  0.18547356]), 3), (True, array([-0.03807275,  0.20845527]), 0), (False, array([-0.93429014, -0.00643129]), 0), (False, array([-0.2648041 , -0.22212355]), 0)]
# [True, False, 0, False, (False, array([-0.10481767, -0.00116844]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([ 0.68983011, -0.08453762]), 0), (True, array([ 0.72986473, -0.28317383]), 0), (False, array([-0.28417346, -0.25866107]), 0), (False, array([ 0.45063994, -0.39977855]), 0)]
# [True, True, 3, False]
# [True, False, 0, False, (True, array([-0.68983011,  0.08453762]), 3), (True, array([ 0.04003462, -0.19863621]), 0), (False, array([-0.97400357, -0.17412345]), 0), (False, array([-0.23919017, -0.31524093]), 0)]
# [True, False, 0, False, (True, array([-0.72986473,  0.28317383]), 3), (True, array([-0.04003462,  0.19863621]), 0), (False, array([-0.27922479, -0.11660472]), 0)]
# [True, False, 0, False, (False, array([-0.07165602,  0.06578908]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([ 0.67433091, -0.16517712]), 0), (True, array([ 0.68583694, -0.32644903]), 0), (False, array([-0.35801228, -0.23872823]), 0), (False, array([ 0.38579663, -0.36391463]), 0)]
# [True, False, 3, False]
# [True, False, 0, False, (True, array([-0.67433091,  0.16517712]), 3), (True, array([ 0.01150603, -0.16127191]), 0), (False, array([-0.28853428, -0.19873752]), 0)]
# [True, False, 0, False, (True, array([-0.68583694,  0.32644903]), 3), (True, array([-0.01150603,  0.16127191]), 0), (False, array([-0.30004031, -0.0374656 ]), 0)]
# [True, False, 0, False, (False, array([-0.0571339 ,  0.11555744]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([ 0.69264722, -0.25173301]), 0), (True, array([ 0.6528161 , -0.35890543]), 0), (False, array([-0.3833914, -0.2637786]), 0), (False, array([ 0.36716415, -0.2970167 ]), 0)]
# [True, True, 3, False]
# [True, False, 0, False, (True, array([-0.69264722,  0.25173301]), 3), (True, array([-0.03983112, -0.10717242]), 0), (False, array([-0.32548307, -0.04528369]), 0)]
# [True, False, 0, False, (True, array([-0.6528161 ,  0.35890543]), 3), (True, array([0.03983112, 0.10717242]), 0), (False, array([-0.28565194,  0.06188874]), 0)]
# [True, False, 0, False, (False, array([-0.05708511,  0.19038243]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([ 0.70638445, -0.31664992]), 0), (True, array([ 0.62805047, -0.38324774]), 0), (False, array([-0.37242574, -0.24256638]), 0), (False, array([ 0.3831898 , -0.24684324]), 0)]
# [True, True, 3, False]
# [True, False, 0, False, (True, array([-0.70638445,  0.31664992]), 3), (True, array([-0.07833398, -0.06659782]), 0), (False, array([-0.32319465,  0.06980668]), 0)]
# [True, False, 0, False, (True, array([-0.62805047,  0.38324774]), 3), (True, array([0.07833398, 0.06659782]), 0), (False, array([-0.24486067,  0.1364045 ]), 0)]
# [True, False, 0, False, (False, array([-0.05706609,  0.25653675]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([ 0.72911215, -0.33190661]), 0), (True, array([ 0.60567521, -0.42943906]), 0), (False, array([-0.29420149, -0.22665721]), 0), (False, array([ 0.42520903, -0.20921315]), 0)]
# [True, True, 3, False]
# [True, False, 0, False, (True, array([-0.72911215,  0.33190661]), 3), (True, array([-0.12343694, -0.09753245]), 0), (False, array([-0.30390313,  0.12269346]), 0)]
# [True, False, 0, False, (True, array([-0.60567521,  0.42943906]), 3), (True, array([0.12343694, 0.09753245]), 0), (False, array([-0.8998767 ,  0.20278184]), 0), (False, array([-0.18046618,  0.2202259 ]), 0)]
# [True, False, 0, False, (False, array([-0.05705184,  0.27615249]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([ 0.78210481, -0.31278788]), 0), (True, array([ 0.59446547, -0.47186786]), 0), (False, array([-0.20553331, -0.17472534]), 0), (False, array([ 0.48672345, -0.22099058]), 0)]
# [True, True, 3, False]
# [True, False, 0, False, (True, array([-0.78210481,  0.31278788]), 3), (True, array([-0.18763934, -0.15907998]), 0), (False, array([-0.98763812,  0.13806254]), 0), (False, array([-0.29538137,  0.09179729]), 0)]
# [True, False, 0, False, (True, array([-0.59446547,  0.47186786]), 3), (True, array([0.18763934, 0.15907998]), 0), (False, array([-0.79999878,  0.29714252]), 0), (False, array([-0.10774202,  0.25087727]), 0)]
# [True, False, 0, False, (False, array([-0.09704114,  0.26086429]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([ 0.82184983, -0.29844842]), 0), (True, array([ 0.61605765, -0.47368987]), 0), (False, array([-0.10903217, -0.13577643]), 0), (False, array([ 0.56285927, -0.22982366]), 0)]
# [True, True, 0, False]
# [True, False, 0, False, (True, array([-0.82184983,  0.29844842]), 3), (True, array([-0.20579218, -0.17524145]), 0), (False, array([-0.930882  ,  0.16267199]), 0), (False, array([-0.25899056,  0.06862476]), 0)]
# [True, False, 0, False, (True, array([-0.61605765,  0.47368987]), 3), (True, array([0.20579218, 0.17524145]), 0), (False, array([-0.72508982,  0.33791343]), 0), (False, array([-0.05319838,  0.24386621]), 0)]
# [True, False, 0, False, (False, array([-0.12703312,  0.21939815]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([ 0.85165859, -0.28769383]), 0), (True, array([ 0.66225178, -0.44505638]), 0), (False, array([-0.00665631, -0.06656475]), 0), (False, array([ 0.68996113, -0.23644846]), 0)]
# [True, True, 0, False]
# [True, False, 0, False, (True, array([-0.85165859,  0.28769383]), 3), (True, array([-0.18940681, -0.15736255]), 0), (False, array([-0.8583149 ,  0.22112907]), 0), (False, array([-0.16169746,  0.05124536]), 0)]
# [True, False, 0, False, (True, array([-0.66225178,  0.44505638]), 3), (True, array([0.18940681, 0.15736255]), 0), (False, array([-0.6689081 ,  0.37849162]), 0), (False, array([0.02770934, 0.20860791]), 0)]
# [True, False, 0, False, (False, array([-0.14952711,  0.11829854]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([ 0.84401516, -0.24962788]), 0), (True, array([ 0.69689738, -0.36358126]), 0), (False, array([0.11012558, 0.015344  ]), 0), (False, array([ 0.82528753, -0.21141707]), 0)]
# [True, False, 0, False]
# [True, False, 0, False, (True, array([-0.84401516,  0.24962788]), 3), (True, array([-0.14711778, -0.11395338]), 0), (False, array([-0.73388958,  0.26497188]), 0), (False, array([-0.01872764,  0.03821081]), 0)]
# [True, False, 0, False, (True, array([-0.69689738,  0.36358126]), 3), (True, array([0.14711778, 0.11395338]), 0), (False, array([-0.58677181,  0.37892526]), 0), (False, array([0.12839014, 0.15216419]), 0)]
# [True, False, 0, False, (False, array([-0.1663976 ,  0.01247383]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([ 0.80250124, -0.24889334]), 0), (True, array([ 0.71710023, -0.30028984]), 0), (False, array([ 0.18614929, -0.00885427]), 0), (False, array([ 0.92100097, -0.22045844]), 0)]
# [True, False, 0, False]
# [True, False, 0, False, (True, array([-0.80250124,  0.24889334]), 3), (True, array([-0.08540101, -0.0513965 ]), 0), (False, array([-0.61635195,  0.24003907]), 0), (False, array([0.11849973, 0.0284349 ]), 0)]
# [True, False, 0, False, (True, array([-0.71710023,  0.30028984]), 3), (True, array([0.08540101, 0.0513965 ]), 0), (False, array([-0.53095094,  0.29143557]), 0), (False, array([0.20390074, 0.0798314 ]), 0)]
# [True, False, 0, False, (False, array([-0.10905046, -0.0668947 ]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([ 0.79132882, -0.29046954]), 0), (True, array([ 0.71593084, -0.22091544]), 0), (False, array([ 0.24052403, -0.02319129]), 0), (False, array([ 0.94017998, -0.15130069]), 0)]
# [True, False, 0, False]
# [True, False, 0, False, (True, array([-0.79132882,  0.29046954]), 3), (True, array([-0.07539797,  0.0695541 ]), 0), (False, array([-0.55080479,  0.26727825]), 0), (False, array([0.14885117, 0.13916884]), 0)]
# [True, False, 0, False, (True, array([-0.71593084,  0.22091544]), 3), (True, array([ 0.07539797, -0.0695541 ]), 0), (False, array([-0.47540682,  0.19772415]), 0), (False, array([0.22424914, 0.06961474]), 0)]
# [True, False, 0, False, (False, array([-0.03604011, -0.0864211 ]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([ 0.82297761, -0.29644314]), 0), (True, array([ 0.67193449, -0.18733493]), 0), (False, array([ 0.21130507, -0.03394405]), 0), (False, array([ 0.92765544, -0.09869062]), 0)]
# [True, False, 0, False]
# [True, False, 0, False, (True, array([-0.82297761,  0.29644314]), 3), (True, array([-0.15104313,  0.10910821]), 0), (False, array([-0.61167254,  0.26249909]), 0), (False, array([0.10467783, 0.19775252]), 0)]
# [True, False, 0, False, (True, array([-0.67193449,  0.18733493]), 3), (True, array([ 0.15104313, -0.10910821]), 0), (False, array([-0.46062941,  0.15339088]), 0), (False, array([0.25572096, 0.08864431]), 0)]
# [True, False, 0, False, (False, array([ 0.04862924, -0.10112013]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([ 0.8755508 , -0.33089777]), 0), (True, array([ 0.60408259, -0.1299964 ]), 0), (False, array([ 0.15939086, -0.08200862]), 0), (False, array([ 0.88826203, -0.01923307]), 0)]
# [True, False, 0, False]
# [True, False, 0, False, (True, array([-0.8755508 ,  0.33089777]), 3), (True, array([-0.27146821,  0.20090137]), 0), (False, array([-0.71615994,  0.24888915]), 0), (False, array([0.01271124, 0.3116647 ]), 0)]
# [True, False, 0, False, (True, array([-0.60408259,  0.1299964 ]), 3), (True, array([ 0.27146821, -0.20090137]), 0), (False, array([-0.44469173,  0.04798778]), 0), (False, array([0.28417944, 0.11076334]), 0)]
# [True, False, 0, False, (False, array([ 0.08798639, -0.14004173]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([ 0.88498068, -0.32673875]), 0), (True, array([ 0.55319367, -0.08699251]), 0), (False, array([ 0.1304552 , -0.11805705]), 0), (False, array([0.82871698, 0.0403601 ]), 0)]
# [True, False, 1, False]
# [True, False, 0, False, (True, array([-0.88498068,  0.32673875]), 3), (True, array([-0.33178701,  0.23974624]), 0), (False, array([-0.75452548,  0.2086817 ]), 0), (False, array([-0.05626371,  0.36709884]), 0)]
# [True, False, 0, False, (True, array([-0.55319367,  0.08699251]), 3), (True, array([ 0.33178701, -0.23974624]), 0), (False, array([-0.42273847, -0.03106454]), 0), (False, array([0.27552331, 0.12735261]), 0)]
# [True, False, 0, False, (False, array([ 0.08859434, -0.16229379]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([ 0.8620531 , -0.29361948]), 0), (True, array([ 0.51502698, -0.05473959]), 0), (False, array([ 0.11875346, -0.14509337]), 0), (False, array([0.71405819, 0.08505497]), 0)]
# [True, False, 1, False]
# [True, False, 0, False, (True, array([-0.8620531 ,  0.29361948]), 3), (True, array([-0.34702612,  0.23887989]), 0), (False, array([-0.74329965,  0.14852611]), 0), (False, array([-0.14799491,  0.37867445]), 0)]
# [True, False, 0, False, (True, array([-0.51502698,  0.05473959]), 3), (True, array([ 0.34702612, -0.23887989]), 0), (False, array([-0.39627353, -0.09035378]), 0), (False, array([0.19903121, 0.13979456]), 0)]
# [True, False, 0, False, (False, array([ 0.0890503 , -0.14898282]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([ 0.81485741, -0.23878003]), 0), (True, array([ 0.48640196, -0.0305499 ]), 0), (False, array([ 0.07997715, -0.16537061]), 0), (False, array([0.59806409, 0.07857613]), 0)]
# [True, False, 2, False]
# ...
# [True, False, 1, False]
# [True, False, 0, False, (True, array([ 0.0894856 , -0.50646343]), 3), (True, array([-0.41440866, -0.34204194]), 0), (False, array([ 0.02642227, -0.67399873]), 0)]
# [True, True, 0, False, (True, array([ 0.50389426, -0.16442149]), 3), (True, array([0.41440866, 0.34204194]), 0), (False, array([ 0.44083094, -0.33195679]), 0)]
# [True, False, 0, False, (False, array([ 0.17321729, -0.13192554]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([-0.09440923,  0.54042201]), 0), (True, array([-0.46678548,  0.22105216]), 0), (False, array([-0.10875825, -0.05996862]), 0)]
# [True, False, 2, False]
# [True, False, 0, False, (True, array([ 0.09440923, -0.54042201]), 3), (True, array([-0.37237625, -0.31936985]), 0), (False, array([-0.01434902, -0.60039063]), 0)]
# [True, True, 0, False, (True, array([ 0.46678548, -0.22105216]), 3), (True, array([0.37237625, 0.31936985]), 0), (False, array([ 0.35802723, -0.28102078]), 0)]
# [True, False, 0, False, (False, array([ 0.18735887, -0.08208167]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([-0.09794467,  0.56091438]), 0), (True, array([-0.40879661,  0.2885486 ]), 0), (False, array([-0.14287216,  0.04572983]), 0)]
# [True, False, 2, False]
# [True, False, 0, False, (True, array([ 0.09794467, -0.56091438]), 3), (True, array([-0.31085193, -0.27236578]), 0), (False, array([-0.04492749, -0.51518455]), 0)]
# [True, True, 0, False, (True, array([ 0.40879661, -0.2885486 ]), 3), (True, array([0.31085193, 0.27236578]), 0), (False, array([ 0.26592444, -0.24281877]), 0)]
# [True, False, 0, False, (False, array([ 0.20796506, -0.04469878]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([-0.07162434,  0.54571679]), 0), (True, array([-0.30633304,  0.33860405]), 0), (False, array([-0.18051376,  0.12386991]), 0)]
# [True, True, 2, False]
# [True, False, 0, False, (True, array([ 0.07162434, -0.54571679]), 3), (True, array([-0.2347087 , -0.20711273]), 0), (False, array([-0.10888942, -0.42184687]), 0)]
# [True, True, 0, False, (True, array([ 0.30633304, -0.33860405]), 3), (True, array([0.2347087 , 0.20711273]), 0), (False, array([ 0.12581928, -0.21473414]), 0)]
# [True, False, 0, False, (False, array([ 0.1934197, -0.0166616]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([-0.02188408,  0.50431859]), 0), (True, array([-0.16948536,  0.37614564]), 0), (False, array([-0.17874496,  0.18247497]), 0)]
# [True, True, 2, False]
# [True, False, 0, False, (True, array([ 0.02188408, -0.50431859]), 3), (True, array([-0.14760127, -0.12817295]), 0), (False, array([-0.15686087, -0.32184361]), 0)]
# [True, True, 0, False, (True, array([ 0.16948536, -0.37614564]), 3), (True, array([0.14760127, 0.12817295]), 0), (False, array([-0.0092596 , -0.19367067]), 0)]
# [True, False, 0, False, (False, array([0.19251068, 0.00436628]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([0.04542558, 0.44616628]), 0), (True, array([-0.0368496 ,  0.37430183]), 0), (False, array([-0.14741835,  0.22642877]), 0)]
# [True, False, 2, False]
# [True, False, 0, False, (True, array([-0.04542558, -0.44616628]), 3), (True, array([-0.08227517, -0.07186445]), 0), (False, array([-0.19284393, -0.21973752]), 0)]
# [True, True, 0, False, (True, array([ 0.0368496 , -0.37430183]), 3), (True, array([0.08227517, 0.07186445]), 0), (False, array([-0.11056876, -0.14787306]), 0)]
# [True, False, 0, False, (False, array([0.16182891, 0.02013719]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([0.09591334, 0.34755203]), 0), (True, array([0.06262722, 0.31291898]), 0), (False, array([-0.1239234 ,  0.22939412]), 0)]
# [True, False, 2, False]
# [True, False, 0, False, (True, array([-0.09591334, -0.34755203]), 3), (True, array([-0.03328612, -0.03463305]), 0), (False, array([-0.21983674, -0.11815791]), 0)]
# [True, True, 0, False, (True, array([-0.06262722, -0.31291898]), 3), (True, array([0.03328612, 0.03463305]), 0), (False, array([-0.18655062, -0.08352486]), 0)]
# [True, False, 0, False, (False, array([ 0.10881759, -0.00803463]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([0.16447641, 0.2404043 ]), 0), (True, array([0.10630496, 0.18412249]), 0), (False, array([-0.10630219,  0.20161813]), 0)]
# [True, False, 2, False]
# [True, False, 0, False, (True, array([-0.16447641, -0.2404043 ]), 3), (True, array([-0.05817144, -0.0562818 ]), 0), (False, array([-0.27077859, -0.03878617]), 0)]
# [True, True, 0, False, (True, array([-0.10630496, -0.18412249]), 3), (True, array([0.05817144, 0.0562818 ]), 0), (False, array([-0.21260715,  0.01749563]), 0)]
# [True, False, 0, False, (False, array([-0.00094091, -0.0291635 ]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([0.25655473, 0.20355864]), 0), (True, array([0.08030554, 0.04853288]), 0), (False, array([-0.09308628,  0.15078614]), 0)]
# [True, False, 2, False]
# [True, False, 0, False, (True, array([-0.25655473, -0.20355864]), 3), (True, array([-0.17624919, -0.15502576]), 0), (False, array([-0.34964101, -0.05277251]), 0)]
# [True, True, 0, False, (True, array([-0.08030554, -0.04853288]), 3), (True, array([0.17624919, 0.15502576]), 0), (False, array([-0.17339182,  0.10225325]), 0)]
# [True, False, 0, False, (False, array([-0.04157364, -0.04734971]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([0.34524452, 0.19394324]), 0), (True, array([ 0.02808347, -0.08799033]), 0), (False, array([-0.08317435,  0.08266214]), 0)]
# [True, False, 2, False]
# [True, False, 0, False, (True, array([-0.34524452, -0.19394324]), 3), (True, array([-0.31716105, -0.28193356]), 0), (False, array([-0.42841887, -0.11128109]), 0)]
# [True, True, 0, False, (True, array([-0.02808347,  0.08799033]), 3), (True, array([0.31716105, 0.28193356]), 0), (False, array([-0.11125782,  0.17065247]), 0)]
# [True, False, 0, False, (False, array([-0.08333406, -0.23611668]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([0.42983308, 0.18578366]), 0), (True, array([ 0.05505934, -0.16227879]), 0), (False, array([-0.02766919,  0.03062112]), 0)]
# [True, False, 3, False]
# [True, False, 0, False, (True, array([-0.42983308, -0.18578366]), 3), (True, array([-0.37477374, -0.34806245]), 0), (False, array([-0.45750226, -0.15516254]), 0)]
# [True, True, 0, False, (True, array([-0.05505934,  0.16227879]), 3), (True, array([0.37477374, 0.34806245]), 0), (False, array([-0.08272852,  0.19289991]), 0)]
# [True, False, 0, False, (False, array([-0.18592388, -0.42122394]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([0.48641205, 0.14884975]), 0), (True, array([ 0.1159535 , -0.27371723]), 0), (False, array([ 0.03161036, -0.07377077]), 0)]
# [True, False, 0, False]
# [True, False, 0, False, (True, array([-0.48641205, -0.14884975]), 3), (True, array([-0.37045856, -0.42256698]), 0), (False, array([-0.45480169, -0.22262052]), 0)]
# [True, True, 0, False, (True, array([-0.1159535 ,  0.27371723]), 3), (True, array([0.37045856, 0.42256698]), 0), (False, array([-0.08434314,  0.19994646]), 0)]
# [True, False, 0, False, (False, array([-0.26286625, -0.53005438]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([0.44271068, 0.15327385]), 0), (True, array([ 0.1054885 , -0.29517153]), 0), (False, array([-0.0362012 , -0.05781562]), 0)]
# [True, False, 0, False]
# [True, False, 0, False, (True, array([-0.44271068, -0.15327385]), 3), (True, array([-0.33722217, -0.44844538]), 0), (False, array([-0.47891188, -0.21108947]), 0)]
# [True, True, 0, False, (True, array([-0.1054885 ,  0.29517153]), 3), (True, array([0.33722217, 0.44844538]), 0), (False, array([-0.14168971,  0.2373559 ]), 0)]
# [True, False, 0, False, (False, array([-0.28057302, -0.58167721]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([0.39755672, 0.14546636]), 0), (True, array([ 0.11526183, -0.29238781]), 0), (False, array([-0.09181573, -0.09810039]), 0)]
# [True, False, 0, False]
# [True, False, 0, False, (True, array([-0.39755672, -0.14546636]), 3), (True, array([-0.28229489, -0.43785417]), 0), (False, array([-0.48937245, -0.24356675]), 0)]
# [True, True, 0, False, (True, array([-0.11526183,  0.29238781]), 3), (True, array([0.28229489, 0.43785417]), 0), (False, array([-0.20707756,  0.19428742]), 0)]
# [True, False, 0, False, (False, array([-0.2938531 , -0.63039433]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([0.30355506, 0.12148134]), 0), (True, array([ 0.09245564, -0.27842944]), 0), (False, array([-0.153799  , -0.19457279]), 0)]
# [True, False, 0, False]
# [True, False, 0, False, (True, array([-0.30355506, -0.12148134]), 3), (True, array([-0.21109942, -0.39991077]), 0), (False, array([-0.45735406, -0.31605413]), 0)]
# [True, True, 0, False, (True, array([-0.09245564,  0.27842944]), 3), (True, array([0.21109942, 0.39991077]), 0), (False, array([-0.24625464,  0.08385665]), 0)]
# [True, False, 0, False, (False, array([-0.30381316, -0.63693217]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([0.20305376, 0.13349251]), 0), (True, array([ 0.04535093, -0.23796072]), 0), (False, array([-0.20028657, -0.27692721]), 0)]
# [True, False, 0, False]
# [True, False, 0, False, (True, array([-0.20305376, -0.13349251]), 3), (True, array([-0.15770282, -0.37145322]), 0), (False, array([-0.40334033, -0.41041972]), 0)]
# [True, True, 0, False, (True, array([-0.04535093,  0.23796072]), 3), (True, array([0.15770282, 0.37145322]), 0), (False, array([-0.24563751, -0.03896649]), 0)]
# [True, False, 0, False, (False, array([-0.31128321, -0.57183555]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([0.09767778, 0.17250088]), 0), (True, array([-0.01997759, -0.17760918]), 0), (False, array([-0.23515225, -0.30869303]), 0)]
# [True, False, 0, False]
# [True, False, 0, False, (True, array([-0.09767778, -0.17250088]), 3), (True, array([-0.11765537, -0.35011006]), 0), (False, array([-0.33283003, -0.48119391]), 0)]
# [True, True, 0, False, (True, array([0.01997759, 0.17760918]), 3), (True, array([0.11765537, 0.35011006]), 0), (False, array([-0.21517466, -0.13108385]), 0)]
# [True, False, 0, False, (False, array([-0.27688574, -0.49301309]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([0.0186458 , 0.20175716]), 0), (True, array([-0.09897399, -0.10234552]), 0), (False, array([-0.22130151, -0.30251739]), 0)]
# [True, False, 0, False]
# [True, False, 0, False, (True, array([-0.0186458 , -0.20175716]), 3), (True, array([-0.11761978, -0.30410269]), 0), (False, array([-0.23994731, -0.50427455]), 0)]
# [True, True, 0, False, (True, array([0.09897399, 0.10234552]), 3), (True, array([0.11761978, 0.30410269]), 0), (False, array([-0.12232752, -0.20017187]), 0)]
# [True, False, 0, False, (False, array([-0.25108764, -0.40389624]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([-0.04062819,  0.22369937]), 0), (True, array([-0.18822128, -0.01589778]), 0), (False, array([-0.21091345, -0.26788566]), 0)]
# [True, False, 1, False]
# [True, False, 0, False, (True, array([ 0.04062819, -0.22369937]), 3), (True, array([-0.14759309, -0.23959716]), 0), (False, array([-0.17028526, -0.49158504]), 0)]
# [True, True, 0, False, (True, array([0.18822128, 0.01589778]), 3), (True, array([0.14759309, 0.23959716]), 0), (False, array([-0.02269217, -0.25198788]), 0)]
# [True, False, 0, False, (False, array([-0.23152669, -0.3496932 ]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([-0.09038512,  0.234674  ]), 0), (True, array([-0.26575963,  0.03797396]), 0), (False, array([-0.24842385, -0.2173939 ]), 0)]
# [True, False, 1, False]
# [True, False, 0, False, (True, array([ 0.09038512, -0.234674  ]), 3), (True, array([-0.17537451, -0.19670004]), 0), (False, array([-0.15803873, -0.4520679 ]), 0)]
# [True, True, 0, False, (True, array([ 0.26575963, -0.03797396]), 3), (True, array([0.17537451, 0.19670004]), 0), (False, array([ 0.01733578, -0.25536786]), 0)]
# [True, False, 0, False, (False, array([-0.21657281, -0.24396348]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([-0.12770282,  0.24290497]), 0), (True, array([-0.3239134 ,  0.07837777]), 0), (False, array([-0.23655665, -0.14952507]), 0)]
# [True, False, 1, False]
# [True, False, 0, False, (True, array([ 0.12770282, -0.24290497]), 3), (True, array([-0.19621058, -0.16452721]), 0), (False, array([-0.10885383, -0.39243005]), 0)]
# [True, True, 0, False, (True, array([ 0.3239134 , -0.07837777]), 3), (True, array([0.19621058, 0.16452721]), 0), (False, array([ 0.08735675, -0.22790284]), 0)]
# [True, False, 0, False, (False, array([-0.20515367, -0.17962663]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([-0.12569109,  0.2190782 ]), 0), (True, array([-0.33752872,  0.07868062]), 0), (False, array([-0.19765625, -0.13862346]), 0)]
# [True, False, 1, False]
# [True, False, 0, False, (True, array([ 0.12569109, -0.2190782 ]), 3), (True, array([-0.21183763, -0.14039758]), 0), (False, array([-0.07196516, -0.35770166]), 0)]
# [True, True, 0, False, (True, array([ 0.33752872, -0.07868062]), 3), (True, array([0.21183763, 0.14039758]), 0), (False, array([ 0.13987247, -0.21730408]), 0)]
# [True, False, 0, False, (False, array([-0.15644326, -0.10635381]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([-0.09418229,  0.17120812]), 0), (True, array([-0.31774021,  0.04890776]), 0), (False, array([-0.13848094, -0.17044724]), 0)]
# [True, False, 2, False]
# [True, False, 0, False, (True, array([ 0.09418229, -0.17120812]), 3), (True, array([-0.22355791, -0.12230036]), 0), (False, array([-0.04429865, -0.34165537]), 0)]
# [True, True, 0, False, (True, array([ 0.31774021, -0.04890776]), 3), (True, array([0.22355791, 0.12230036]), 0), (False, array([ 0.17925926, -0.21935501]), 0)]
# [True, False, 0, False, (False, array([-0.08991046, -0.05139919]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# [True, False, 3, False, (True, array([-0.04009761,  0.10898342]), 0), (True, array([-0.27289883, -0.00342188]), 0), (False, array([-0.06409947, -0.15431508]), 0)]
# [True, False, 2, False]
# [True, False, 0, False, (True, array([ 0.04009761, -0.10898342]), 3), (True, array([-0.23280122, -0.1124053 ]), 0), (False, array([-0.02400186, -0.2632985 ]), 0)]
# [True, True, 0, False, (True, array([0.27289883, 0.00342188]), 3), (True, array([0.23280122, 0.1124053 ]), 0), (False, array([ 0.20879936, -0.1508932 ]), 0)]
# [True, False, 0, False, (False, array([-0.01001085, -0.01018322]), 0)]
# [False, False, 0, False]
# [False, False, 0, False]
# [False, False, 0, False]
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
